# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv('~/Downloads/mytable_customer_details - Ref_CustDetails.csv')
pd.set_option('max_columns', None)
pd.crosstab(df['contract_type.1'], df.churn, margins=True)
# Out:
# churn              No   Yes   All
# contract_type.1
# 1 Year           1307   166  1473
# 2 Year           1647    48  1695
# Month-to-Month   2220  1655  3875
# All              5174  1869  7043

# %%
m2m = df[df["contract_type.1"] == "Month-to-Month"]

# %%
df
# Out:
#      customer_id  gender is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                No     Yes        Yes              1
# 1     0003-MKNFE    Male                No      No         No              2
# 2     0004-TLHLJ    Male                No      No         No              1
# 3     0011-IGKFF    Male               Yes     Yes         No              1
# 4     0013-EXCHZ  Female               Yes     Yes         No              1
# ...          ...     ...               ...     ...        ...            ...
# 7038  9987-LUTYD  Female                No      No         No              1
# 7039  9992-RRAMN    Male                No     Yes         No              2
# 7040  9992-UJOEL    Male                No      No         No              1
# 7041  9993-LHIEB    Male                No     Yes        Yes              1
# 7042  9995-HOTOH    Male                No     Yes        Yes              0
#
# ...

# %%
m2m.to_csv("MonthToMonth.csv")
m2m.groupby('churn').Services.agg('count')
# Out:
# churn
# No     2220
# Yes    1655
# Name: Services, dtype: int64

# %%
pd.crosstab(m2m.churn, m2m.Services, margins=True)
# Out:
# Services  Internet  Phone  Phone and Internet   All
# churn
# No             223    425                1572  2220
# Yes            153     99                1403  1655
# All            376    524                2975  3875

# %%
z = m2m[m2m.Services == "Phone and Internet"]

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2975 entries, 1 to 7040
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              2975 non-null   object
#  1   gender                   2975 non-null   object
#  2   is_senior_citizen        2975 non-null   object
#  3   partner                  2975 non-null   object
#  4   dependents               2975 non-null   object
#  5   phone_service            2975 non-null   int64
#  6   internet_service         2975 non-null   int64
#  7   contract_type            2975 non-null   int64
#  8   payment_type             2975 non-null   object
#  9   monthly_charges          2975 non-null   object
#  10  total_charges            2975 non-null   object
#  11  churn                    2975 non-null   object
#  12  tenure_months            2975 non-null   float64
#  13  is_female                2975 non-null   bool
# ...

# %%
x = z[z.churn == "Yes"]
y = m2m[m2m.Services == "Phone and Internet"]
y = y[y.churn == "No"]

# %%
x["monthly_charges"] = x["monthly_charges"].str.strip("$").astype(float)
y["monthly_charges"] = y["monthly_charges"].str.strip("$").astype(float)

# %%
x.monthly_charges.mean()
# Out:
# 80.73513898788298

# %%
x
# Out:
#      customer_id  gender is_senior_citizen partner dependents  phone_service  \
# 2     0004-TLHLJ    Male                No      No         No              1
# 3     0011-IGKFF    Male               Yes     Yes         No              1
# 4     0013-EXCHZ  Female               Yes     Yes         No              1
# 21    0023-XUOPT  Female                No     Yes         No              2
# 40    0067-DKWBL    Male               Yes      No         No              1
# ...          ...     ...               ...     ...        ...            ...
# 7013  9948-YPTDG    Male                No     Yes         No              1
# 7020  9961-JBNMK    Male               Yes      No         No              1
# 7023  9965-YOKZB    Male               Yes      No         No              2
# 7036  9985-MWVIX  Female                No      No         No              1
# 7039  9992-RRAMN    Male                No     Yes         No              2
#
# ...

# %%
y.monthly_charges.mean()
# Out:
# 76.0073155216286

# %%
x.tenure_month_ages.median()
# Out:
# 9.0

# %%
x["adjusted_yearly_charges"] = x.monthly_charges * 11

# %%
y["adjusted_yearly_charges"] = y.monthly_charges * 11

# %%
x["yearly_charges"] = x.monthly_charges * 12

# %%
y["yearly_charges"] = y.monthly_charges * 12

# %%
x
# Out:
#      customer_id  gender is_senior_citizen partner dependents  phone_service  \
# 2     0004-TLHLJ    Male                No      No         No              1
# 3     0011-IGKFF    Male               Yes     Yes         No              1
# 4     0013-EXCHZ  Female               Yes     Yes         No              1
# 21    0023-XUOPT  Female                No     Yes         No              2
# 40    0067-DKWBL    Male               Yes      No         No              1
# ...          ...     ...               ...     ...        ...            ...
# 7013  9948-YPTDG    Male                No     Yes         No              1
# 7020  9961-JBNMK    Male               Yes      No         No              1
# 7023  9965-YOKZB    Male               Yes      No         No              2
# 7036  9985-MWVIX  Female                No      No         No              1
# 7039  9992-RRAMN    Male                No     Yes         No              2
#
# ...

# %%
m2m
# Out:
#      customer_id  gender is_senior_citizen partner dependents  phone_service  \
# 1     0003-MKNFE    Male                No      No         No              2
# 2     0004-TLHLJ    Male                No      No         No              1
# 3     0011-IGKFF    Male               Yes     Yes         No              1
# 4     0013-EXCHZ  Female               Yes     Yes         No              1
# 5     0013-MHZWF  Female                No      No        Yes              1
# ...          ...     ...               ...     ...        ...            ...
# 7033  9975-SKRNR    Male                No      No         No              1
# 7036  9985-MWVIX  Female                No      No         No              1
# 7037  9986-BONCE  Female                No      No         No              1
# 7039  9992-RRAMN    Male                No     Yes         No              2
# 7040  9992-UJOEL    Male                No      No         No              1
#
# ...

# %%
z = x[['churn', 'yearly_charges', 'adjusted_yearly_charges']]

# %%
x.pivot_table(index=tenure_month_ages, yearly_adjusted_charges)
# Out:
#   File "<ipython-input-99-b73b30e6511a>", line 1
#     x.pivot_table(index=tenure_month_ages, yearly_adjusted_charges)
#                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
x.yearly_charges.meadian()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-185c56c0b4fe> in <module>
# ----> 1 x.yearly_charges.meadian()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'meadian'

# %%
x.adjusted_yearly_charges.mean()
# Out:
# 888.0865288667142

# %%
y.yearly_charges.mean()
# Out:
# 912.0877862595421

# %%
y.yearly_charges.mean()
# Out:
# 912.0877862595421

# %%
x.yearly_charges.mean()
# Out:
# 968.8216678545963

# %%
y.shape
# Out:
# (1572, 31)
