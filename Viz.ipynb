# %%
import numpy as np
import pandas as pd
#import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('~/Downloads/mytable_customer_details - Ref_CustDetails.csv')
pd.set_option('max_columns', None)
#pd.reset_option(“max_columns”)
#pd.set_option("max_rows", None)
#pd.reset_option(“max_rows”)

# %%
#m2m = df[(df["contract_type.1"] == "Month-to-Month") & (df.has_churned == True)]
m2m = df[df["contract_type.1"] == "Month-to-Month"]
m2m
# Out:
#      customer_id  gender is_senior_citizen partner dependents  phone_service  \
# 1     0003-MKNFE    Male                No      No         No              2
# 2     0004-TLHLJ    Male                No      No         No              1
# 3     0011-IGKFF    Male               Yes     Yes         No              1
# 4     0013-EXCHZ  Female               Yes     Yes         No              1
# 5     0013-MHZWF  Female                No      No        Yes              1
# ...          ...     ...               ...     ...        ...            ...
# 7033  9975-SKRNR    Male                No      No         No              1
# 7036  9985-MWVIX  Female                No      No         No              1
# 7037  9986-BONCE  Female                No      No         No              1
# 7039  9992-RRAMN    Male                No     Yes         No              2
# 7040  9992-UJOEL    Male                No      No         No              1
#
# ...

# %%
m2mplot = pd.crosstab(m2m.Services, m2m.churn)
m2mplot.to_csv("totalmembers.csv")

# %%
churned = m2m[m2m.churn == "Yes"]
not_churned = m2m[m2m.churn == "No"]

# %%
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
  
data = [23, 17, 35, 29, 12, 41]
  
# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)
  
# show plot
plt.show()

# %%
sns.heatmap(m2mplot, annot=True, cmap=plt.cm.Greens, fmt='d')
plt.title("Churn and Services")
# Out:
# Text(0.5, 1.0, 'Churn and Services')

# %%
#76 23, 15.6 84%

# %%
m2m[['churn', 'monthly_charges', 'Services']].sample(50)
# Out:
#      churn monthly_charges            Services
# 3236    No          $88.40  Phone and Internet
# 489    Yes          $61.65  Phone and Internet
# 6216    No          $99.80  Phone and Internet
# 6077   Yes          $49.10  Phone and Internet
# 2795    No          $20.60               Phone
# 6624   Yes         $104.80  Phone and Internet
# 3223    No          $20.45               Phone
# 833     No          $48.25            Internet
# 1689   Yes          $92.50  Phone and Internet
# 4561    No          $69.60  Phone and Internet
# 6164    No          $85.95  Phone and Internet
# 6971   Yes          $74.30  Phone and Internet
# 2568   Yes          $80.60  Phone and Internet
# 6371    No          $25.05               Phone
# 4346    No          $44.85            Internet
# 245     No          $44.60  Phone and Internet
# 3925    No          $85.90  Phone and Internet
# 5084    No          $20.45               Phone
# 1396    No         $111.15  Phone and Internet
# ...

# %%
m2m['monthly_charges'] = m2m.monthly_charges.str.strip('$').astype(float)
# Out:
# <ipython-input-10-bf86723753f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m2m['monthly_charges'] = m2m.monthly_charges.str.strip('$').astype(float)

# %%
m2m
# Out:
#      customer_id  gender is_senior_citizen partner dependents  phone_service  \
# 1     0003-MKNFE    Male                No      No         No              2
# 2     0004-TLHLJ    Male                No      No         No              1
# 3     0011-IGKFF    Male               Yes     Yes         No              1
# 4     0013-EXCHZ  Female               Yes     Yes         No              1
# 5     0013-MHZWF  Female                No      No        Yes              1
# ...          ...     ...               ...     ...        ...            ...
# 7033  9975-SKRNR    Male                No      No         No              1
# 7036  9985-MWVIX  Female                No      No         No              1
# 7037  9986-BONCE  Female                No      No         No              1
# 7039  9992-RRAMN    Male                No     Yes         No              2
# 7040  9992-UJOEL    Male                No      No         No              1
#
# ...

# %%
x = m2m[['churn', 'Services', "monthly_charges"]]

# %%
data = m2m.pivot_table(index='churn', columns='Services', values='monthly_charges')

# %%
data
# Out:
# Services   Internet      Phone  Phone and Internet
# churn
# No        37.070852  20.462941           76.007316
# Yes       36.456536  20.180303           80.735139

# %%
sns.catplot(x='Services', y='monthly_charges', hue="churn", data=x, kind='bar')
plt.title('Churn Averages by Service')
# Out:
# Text(0.5, 1.0, 'Churn Averages by Service')

# %%
y = pd.crosstab(x.churn, x.Services)
sns.heatmap(y, annot=True, cmap="YlGnBu", fmt='d')
plt.title("Churn Totals by Service")
# Out:
# Text(0.5, 1.0, 'Churn Totals by Service')
